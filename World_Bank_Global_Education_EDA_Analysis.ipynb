# %% [markdown]
# # **Project Name**    - ***World Bank Global Education Analysis***
#
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1** - Ruben Stanley John Benedict Lobo

# %% [markdown]
# # **Project Summary & Objectives**

# %% [markdown]
# ***
# In this project we are going to analyze the World Bank EdStats Data in order to find out valuable insights regarding education across various countries & regions. The World Bank’s Global Education dataset, available through the EdStats All Indicator Query, serves as a comprehensive resource for analyzing global education trends, policies, and performance metrics. The dataset holds over 4,000 internationally comparable indicators that describe education access, progression, completion, literacy, teachers, population, and expenditures.The indicators cover the education cycle from pre-primary to vocational and tertiary education and also hold learning outcome data from international and regional learning assessments (e.g. PISA, TIMSS, PIRLS), equity data from household surveys, and projection/attainment data. This project focuses on extracting, processing, and analyzing data from this repository to uncover insights into educational access, quality, and disparities worldwide. By leveraging Python and data analysis libraries, the project aims to provide meaningful visualizations and statistical interpretations that can aid policymakers, researchers, and educators in making informed decisions.
#
# The key objectives of this project are:
#
# 1. Data Extraction and Preprocessing: Retrieve and clean the dataset to ensure consistency, handle missing values, and structure the data for analysis.
#
# 2. Exploratory Data Analysis (EDA): Identify trends, correlations, and outliers in global education metrics.
#
# 3. Comparative Analysis: Evaluate education indicators across different countries, income groups, and regions.
#
# 4. Time-Series Analysis: Assess trends in education indicators over time to understand progress and setbacks.
#
# 5. Data Visualization: Create interactive charts and dashboards to communicate findings effectively.
# ***

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/rubenslobo/Ruben-Projects/blob/main/World_Bank_Global_Education_EDA_Analysis.ipynb

# %% [markdown]
# ##**<u>Problem Statement</u>:-**
# To identify key world markets for investment in education as well as to ascertain whether the education sector in India has great potential for investment.

# %% [markdown]
# ##**<u>The following Indicators in the data have been chosen for analysis</u>:-**
#
# **Early Childhood Education**
# * Enrolment in early childhood education, both sexes (number) -**UIS.E.0.T**
# * Percentage of enrolment in pre-primary education in private institutions (%) - **SE.PRE.PRIV.ZS**
#
# **Expenditures**
#
# * Government expenditure on education as % of GDP (%) - **SE.XPD.TOTL.GD.ZS**
# * Expenditure on education as % of total government expenditure (%) **SE.XPD.TOTL.GB.ZS**
#
# **Literacy**
#
# * Adult literacy rate, population 15+ years, both sexes (%) - **SE.ADT.LITR.ZS**
# * Adult illiterate population, 15+ years, both sexes (number) - **UIS.LP.AG15T99**
#
# **Population**
# * School age population, pre-primary education, both sexes (number) - **SP.PRE.TOTL.IN**
# * School age population, primary education, both sexes (number) - **SP.PRM.TOTL.IN**
# * School age population, secondary education, both sexes (number) - **SP.SEC.TOTL.IN**
# * School age population, tertiary education, both sexes (number) - **SP.TER.TOTL.IN**
#
# **Learning Outcomes**
# * PISA: Mean performance on the Reading scale (number) - **LO.PISA.REA**
# * PISA: Mean performance on the Mathematics scale (number) - **LO.PISA.MAT**

# %%
# List of selected indicators for analysis.
Indicators = ["UIS.E.0.T", "SE.PRE.PRIV.ZS",
              # Early Childhood Education
              "SE.XPD.TOTL.GD.ZS", "SE.XPD.TOTL.GB.ZS",
              # Expenditures
              "SE.ADT.LITR.ZS", "UIS.LP.AG15T99",
              # Literacy
              "SP.PRE.TOTL.IN", "SP.PRM.TOTL.IN", "SP.SEC.TOTL.IN", "SP.TER.TOTL.IN",
              # Population
              "LO.PISA.REA", "LO.PISA.MAT"]
              # Learning outcomes

# length of Indicators list.
len(Indicators)
# Out:
# 12

# %% [markdown]
# ##**<u>Also, Following Countries have been selected for Analysis</u>:-**
# * **India->** IND
# * **United States->** USA
# * **United Kingdom->** GBR
# * **Australia->** AUS
# * **Germany->** DEU
# * **South Africa->** ZAF
# * **Canada->** CAN
# * **Japan->** JPN
# * **Sri Lanka->** LKA

# %%
# List of countries that have been selected for analysis.
Countries = ["India", "United States", "United Kingdom", "Australia", "Germany",
             "South Africa", "Canada", "Japan", "Sri Lanka"]
len(Countries)
# Out:
# 9

# %% [markdown]
# ## Mounting the Drive
# Now, The first step to be carried out would be to mount the drive in order to extract the Datasets present in the Drive folder.

# %%
# Mounting the Google Drive to access data.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Knowing our Data**
# ******

# %% [markdown]
# **Importing Necessary Modules and Libraries**
#
# In order to access the data, we would first have to import following libraries for their respective applications:
#
#
# *   NumPy:- Numpy stands for Numerical Python and is used for running numerical computations across large multi-dimensional arrays and matrices.
# *   Pandas:- Pandas is a library in Python which includes functions for analyzing, cleaning, exploring, and manipulating data.
# *   Matplotlib:- Matplotlib is a Python library mainly serving as a visualization utility for plotting graphs, charts, and plots. Most of the Matplotlib utilities lie under the pyplot submodule of Matplotlib.
# *   Math:- The math module provides mathematical functions for calculations such as trigonometry, logarithms, and power functions.

# %%
# Importing packages like pandas, matplotlib and math for analysis, visualization and arithematical operations.
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# Now, we would require to load our data from the external source, which in this case is uploaded to the drive. Also we would try to spot the nature and properties of the data that we have. The data is divided into 5 different CSV files, each containing the information as follows:
#
#
# 1.   **EdStatsData**:- This file contains Education Statistics data (from year 1970 to 2100) of all the countries that are World Bank members and this data is dependent on various indicators that resembles various factors that affect the overall Education growth and development of the country. These indicators can be access, availabilty, teachers, expenditures, population, literacy, assessments etc.

# %%
# The variable Data_path contains the path of dataset stored in drive.
# This path is common for all files so this variable can be used multiple times to load respective files.

Data_path = "/content/drive/MyDrive/Almabetter/Capstone Projects/World Bank Global Education Analysis/data/"

# Importing EdStatsData File.
EdStatsData = pd.read_csv(Data_path + "EdStatsData.csv")

# shape of data.
print(EdStatsData.shape)

# Displaying first 3 rows.
EdStatsData.head(3)
# Out:
# (886930, 70)
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  1970  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2   NaN
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F   NaN
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI   NaN
#
#    1971  1972  1973  1974  1975  ...  2060  2065  2070  2075  2080  2085  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2090  2095  2100  Unnamed: 69
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN          NaN
#
# [3 rows x 70 columns]

# %%
# Using the describe function to analyze the nature and paradigm of EdStatsData.
EdStatsData.describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
#Going by the above, it seems that this is a time-series data. Loading in the data columns to see column descriptions and the years covered
EdStatsData.columns
#Post 2017, it appears data is forecasted for every 5 years uptil year 2100
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %% [markdown]
# 2.   **EdStatsCountry**:- This file contains information from census and surveys across various departments, segregated in a country-wise manner.

# %%
# Loading EdStatsCountry file.
EdStatsCountry = pd.read_csv(Data_path + "EdStatsCountry.csv")

# Shape of data.
print(EdStatsCountry.shape)

# Displaying first three rows of data.
EdStatsCountry.head(3)
# Out:
# (241, 32)
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
#
#                       Region          Income Group WB-2 code  ...  \
# 0  Latin America & Caribbean  High income: nonOECD        AW  ...
# 1                 South Asia            Low income        AF  ...
# 2         Sub-Saharan Africa   Upper middle income        AO  ...
#
# ...

# %%
# Using to column attribute to see what type of information is stored in EdStatsCountry file.
EdStatsCountry.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')

# %% [markdown]
# 3. **EdStatsCountry-Series**:- This file contains the Series Code for various indicators, as well as the Data sources from which they have been derived

# %%
# Loading EdStatsCountry_Series file.
EdStatsCountry_Series = pd.read_csv(Data_path + "EdStatsCountry-Series.csv")

# Printing first three rows to analyse the type of data present in this file.
EdStatsCountry_Series.head(3)
# Out:
#   CountryCode   SeriesCode                                        DESCRIPTION  \
# 0         ABW  SP.POP.TOTL  Data sources : United Nations World Population...
# 1         ABW  SP.POP.GROW  Data sources: United Nations World Population ...
# 2         AFG  SP.POP.GROW  Data sources: United Nations World Population ...
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN

# %%
#Loading in the columns
EdStatsCountry_Series.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3'], dtype='object')

# %%
# The shape attribute will reveal to us the number of rows and columns in the EdStatsCountry_Series file
EdStatsCountry_Series.shape
# Out:
# (613, 4)

# %% [markdown]
# 4. **EdStatsFootNote**:- This file contains year wise indicator names along with their respective descrption. It tells us the nature of the indicators, if it's an estimate value or a percentage distribution etc. From context of our analysis this information isn't quite useful, since its already evident with the type of data EdStatsData holds.

# %%
# Loading EdStatsFootNote file.
EdStatsFootNote = pd.read_csv(Data_path + "EdStatsFootNote.csv")

# Displaying first three rows.
EdStatsFootNote.head(3)
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN

# %%
# The shape attribute will reveal to us the number of rows and columns in the EdStatsFootNote file
EdStatsFootNote.shape
# Out:
# (643638, 5)

# %% [markdown]
# 5.   **EdStatsSeries**:- This file contains regional learning assessments data(e.g. PISA, TIMSS, PIRLS), equity data from household surveys, and projection/attainment data.

# %%
# Loading EdStatsSeries file
EdStatsSeries = pd.read_csv(Data_path + "EdStatsSeries.csv")

# displaying first 3 rows.
EdStatsSeries.head(3)
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
#
#                                      Long definition  Unit of measure  \
# 0  Percentage of female population age 15-19 with...              NaN
# 1  Percentage of population age 15-19 with no edu...              NaN
# 2  Percentage of female population age 15+ with n...              NaN
#
#   Periodicity Base Period Other notes Aggregation method  ...  \
# ...

# %%
# The shape attribute will reveal to us the number of rows and columns in EdStatsSeries.
EdStatsSeries.shape
# Out:
# (3665, 21)

# %% [markdown]
# ##**Data Pre-Processing & Mining for Indicators**
# The Data mining is the process of extracting and discovering patterns in large data sets. Data Cleaning is one of the most integral part of analysis, in order to get something meaningful out of a huge dataset we need to figure out how to extract a generalized, smaller and more skewed sub-dataFrame out of it. Like here we have defined two functions, i.e, get_columnwise_data() and get_rowwise_data() to extract out column wise and row wise matrices respectively. Also the function performs some partial cleaning over data such that we only have rows and columns that has some meaningful data to hold. The columns that are all 'NaNs' are dropped such that the data remains cosistent and more skewed. Filling those null columns could effect the analysis, manipulating the graph with values that are not literal and are estimated in one way or the other. Since filling those nulls with a mean or 0, or using forward and backward fill methods, could not make up for the original value, and this is same for all countries so dropping such columns seemed to be the right choice.

# %%
# Function to mine a column-wise sub dataset that would have the selected countries as columns
# with meaningful years (those columns/Years that have at least one available value).
# This type of data is suitable for plotting line charts and getting meaningful insights across trends.

def get_columnwise_data(indicator_code, EdStatsData, Countries):
    # Extract data for the given indicator
    df = EdStatsData[EdStatsData["Indicator Code"] == indicator_code]

    # Filter by selected countries
    df = df[df['Country Name'].isin(Countries)]

    # Drop columns with all NaN values
    df.dropna(how='all', axis=1, inplace=True)

    # Reset index
    df.reset_index(drop=True, inplace=True)

    # Extract indicator name safely
    title = df["Indicator Name"].iloc[0] if not df.empty else "Unknown Indicator"

    # Save country names before transposing
    country_names = df["Country Name"].tolist()

    # Drop unnecessary columns before transposing
    cols_to_drop = ["Country Name", "Country Code", "Indicator Name", "Indicator Code"]
    df.drop(columns=[col for col in cols_to_drop if col in df.columns], inplace=True)

    # Transpose and reset index
    df = df.T.reset_index()

    # Define new column names using the extracted country names
    df.columns = ["Year"] + country_names  # ✅ Uses correct country order

    # Drop the first row safely and reset index
    if not df.empty and 0 in df.index:
        df.drop(0, inplace=True)
        df.reset_index(drop=True, inplace=True)

    return df, title


# Function to mine data in a row-wise manner, with years as columns and countries as rows.
# This type of data helps in plotting graphical representations using bars of different heights
# and analyzing trends over time.

def get_rowwise_data(indicator_code, EdStatsData, Countries):
    # Get column-wise data
    df, title = get_columnwise_data(indicator_code, EdStatsData, Countries)

    # Extracting year list for column names
    cols = list(df["Year"])

    # Transpose the dataframe and also reset the indexes of the columns
    df = df.T.reset_index()

    # Setting new column names (Years)
    df.columns = ["Country Name"] + cols

    # Drop the first row safely and reset index
    if not df.empty and 0 in df.index:
        df.drop(0, inplace=True)
        df.reset_index(drop=True, inplace=True)

    return df, title

# %% [markdown]
# Now, lets just check if the function works as expected. Below is a test run for both functions. We can also use the information retrieved here for future operations on the indicator used.

# %%
# Calling get_rowwise_data() on the indicator present at index 1 in the Indicators list.
# This Indicator is described as "Percentage of enrolment in pre-primary education in private institutions (%)".
# This is just to test if the function is returning the required results.
# Call the function with the indicator at index 1
temp, t = get_rowwise_data(Indicators[1], EdStatsData, Countries)

# Print the indicator title
print(t)

# Display the dataframe
temp
# Out:
# Percentage of enrolment in pre-primary education in private institutions (%)
#      Country Name       1972       1973       1974       1975       1976  \
# 0       Australia        NaN        NaN  21.940889   19.49725  18.816019
# 1          Canada    2.35687    2.26478    2.00116     2.5621    2.47142
# 2         Germany        NaN        NaN        NaN        NaN        NaN
# 3           India        0.0        0.0        NaN        NaN        NaN
# 4           Japan  75.923576  76.596039  75.941681  75.692436   75.10585
# 5    South Africa        NaN        NaN        NaN        NaN        NaN
# 6       Sri Lanka        NaN        NaN        NaN        NaN        NaN
# 7  United Kingdom        NaN        NaN        NaN        NaN    5.39608
# 8   United States   31.34041        NaN   31.81818        NaN    33.1064
#
#         1977       1978       1979       1980  ...       2006       2007  \
# 0   18.76877  19.001471  21.520741   22.47348  ...  82.214394  76.055313
# ...

# %% [markdown]
# It can be now seen from the above table that our functions are working exactly as expected. The dataframe returned has all years as columns, that have at least one not-null value. Though the data still has a lot of 'NaN' values, but those we can handle later.
#
# Here we called the get_rowwise_data() function because it implicitly calls the get_columnwise_data() to get a columnwise data matric, which is then converted to rowwise matric by further operation, this way we can test if both the functions are working as desired.

# %% [markdown]
# ##**Data Analysis and Visualization**
# ******
# Now that we know how to extract the meaningful chunk out of the huge dataset, we can proceed to analyze and visualize the data to get some insights and figure out trends and patterns over it.
#
# So, the first Category to perform analysis on is *Early Childhood Education*.

# %% [markdown]
# ###**Early Childhood Education**
# ******
# Early childhood education (ECE), also called nursery education, refers to the branch of education theory that relates to the teaching of children from birth up to the age of eight. In most cases its refered equivalent to 3rd Grade.
#
# Quality of early childhood education can reflect a significant contribution to the physical, psychomotor, cognitive, social and emotional development of the child, including the acquisition of languages and early age knowledge, which in a long run would reflect towards the countries literacy. The first eight years of a child's life is a period of tremendous growth and development.
#
# As mentioned before we have selected two indicators from this category. Following is the respective analysis based on those indicators:-
#
# 1. Enrolment in early childhood education, both sexes.

# %%
# Calling get_columnwise_data() to get a columnwise matrix along with the title
# for first indicator in the 'Indicators' list.
Indicator1 , Title1  = get_columnwise_data(Indicators[0], EdStatsData, Countries)

# Displaying Title of Indicator.
print(Title1)

# Displaying the DataFrame recieved.
Indicator1
# Out:
# Enrolment in early childhood education, both sexes (number)
#     Year  Australia    Canada    Germany      India      Japan  South Africa  \
# 0   2000        NaN       NaN  2297821.0        NaN  3425697.0           NaN
# 1   2001   272996.0       NaN  2398104.0  2617403.0  3463487.0           NaN
# 2   2002   263541.0       NaN  2352829.0  4623168.0  3492456.0      518985.0
# 3   2003   211627.0       NaN  2316687.0  5507559.0  3555478.0           NaN
# 4   2004   214059.0       NaN  2238270.0  5050006.0  3586547.0           NaN
# 5   2005   221672.0       NaN  2232306.0  4761485.0  3615999.0      685749.0
# 6   2006   212998.0       NaN  2443550.0  5264053.0  3630184.0           NaN
# 7   2007   212402.0  486874.0  2420124.0  5366340.0  3614874.0           NaN
# 8   2008   215526.0       NaN  2410081.0  6576483.0  3606830.0           NaN
# 9   2009   219741.0       NaN  2385856.0  5839725.0  3579867.0      904469.0
# ...

# %% [markdown]
# Now that the DataFrame seems to be ready, we can proceed with further operations as follows:-

# %%
# Now we need to replace the 'NaN' entries with some meaningful
# value since they might affect the visualization to make it inconsistent.

# Firstly using a fillna() with 'ffill' method to perform upward fill for 'NaN' values,
# this will fill 'NaN' with the nearest value above it in the column.
Indicator1.fillna(method = "ffill", inplace = True)

# Now using a fillna() with 'bfill' method to perform downward fill for 'NaN' values,
# this will fill 'NaN' with the nearest value below it in the column.
Indicator1.fillna(method = "bfill", inplace = True)

# Matric after filling NaNs.
Indicator1
# Out:
# <ipython-input-21-5dd182d2da09>:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Indicator1.fillna(method = "ffill", inplace = True)
# <ipython-input-21-5dd182d2da09>:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Indicator1.fillna(method = "bfill", inplace = True)
#     Year  Australia    Canada    Germany      India      Japan  South Africa  \
# 0   2000   272996.0  486874.0  2297821.0  2617403.0  3425697.0      518985.0
# 1   2001   272996.0  486874.0  2398104.0  2617403.0  3463487.0      518985.0
# 2   2002   263541.0  486874.0  2352829.0  4623168.0  3492456.0      518985.0
# 3   2003   211627.0  486874.0  2316687.0  5507559.0  3555478.0      518985.0
# 4   2004   214059.0  486874.0  2238270.0  5050006.0  3586547.0      518985.0
# ...

# %% [markdown]
# Now the data matrix is completely filled and is ready for visualizations. We are going to now use a line plot to visualize this particular indicator because we are looking for patterns and insights over the years (time-series data) for the selected countries and line graph would therefore help us to find trends across various countries.

# %%
# Using plot() from pandas module to plot a line graph,
# this plot function is just the extension to the plot() in matplotlib.

Indicator1.plot(x = "Year", kind='line', title = Title1,
                xlabel = "Years", ylabel = "Estimate Enrolment in ECE",
                ylim = (0, 1e7), figsize=(15,9), fontsize = 11,
                grid = True, linewidth = 2.5,
                marker = "^").patch.set_facecolor('#f0ffff')

# Above function will create and display the graph after successful execution.
# Also we've called another function i.e., patch.set_facecolor() with the plot object,
# this helps us to change the background colour of the plot.
# kind:- Type of graph.
# ylabel and xlabel:- Label of Y-axis and x-axis.
# ylim:- Limit for Y-axis values.
# grid:- 'True' for displaying grid.
# linewidth:- thickness of trend lines.
# marker:- used to show a trend or mark an important value.

# %% [markdown]
# **Observations:**
# ********
#
# We can now deduce the following from the above graph -
#
# **United states** witnessed some fluctuations over the entire trend period, which can explained according to various timeframes. There is a slight but noticeable dip in enrolments between 2007 to 2010 which is attributable to a general reduced household spending and rising unemployment, primarily influenced by the 2007 Subprime crisis in United States and its immediate after-effects well lasting upto 2010. Lower household spending and reduced income opportunities affected self-sustainability, which would also go on to affect early education spending and cause delayed early education enrolments, as evidenced in the graph. Thereafter, we can witness a significant leap occuring in the period from 2010 - 2012 which is around the time, the education and job markets witness a short but steady spending revival, primarily owing to the financial reforms undertaken by the US government and credit protection measures implemented across the country. Then, the same is consequently followed by a minor drop in enrolments due to the looming credit crisis effects & lowered income opportunities experienced by organisations as well as the general population in U.S and Europe. Overall the trend for USA seemed to be consistent, showing a constant positive growth along the entire time period. It's clear from the chart that, part of the reason why USA is an advanced economy, is because they focus a lot towards early age education of children, which contributes significantly to the overall literacy and job readiness in later years.
#
# For **India**, we observe significant leaps in the periods 2001-2003, 2005-2008 and also at 2010-2013, and we are able to notice that the slopes and degrees of hills are more significant than the slopes and degrees of the valleys, which shows positive signs of growth. India, which is a developing country experienced a remarkable rise in its population as well as life expectancy numbers which is evident from the data for school-going children (primary, secondary and post-secondary & tertiary education), primarily due to increase in health awareness and disease control campaigns conducted across India during the same time period. From 2008-2012, India manifests a significant drop in enrolment numbers, primarily affected by curtailment in household spending experienced by lower-income groups, which is in turn triggered by the worsening global financial situation (after-effects of the US Suprime and credit crisis). However the ever increasing trajectory in the graph (2012-2014) is evidence of India's commitment towards early age education, eventually asserting its lead over other countries in coming years, while being second only to US & China.
#
# For **Japan** and **Germany**, we see minor fluctuations throughout, and significant changes in the period 2012-2014. we see a climb for *Germany*, and a drop for *Japan*. Japan's Government endorses a rigorous early education policy such that students enrol into a school only after the age of 8. This clearly affects their rate of early education enrolment. In the same time period, Germany experiences a surge in its population, primarily due to the relaxed open borders policy and the significant migration influx of refugees from new nations, primarily the war-torn Middle-Eastern states like Syria, Iraq and Egypt, thus driving more early education enrolments and increase in spending initiatives by the German government to support the masses.
#
# We can also see a consistent growth trend for the **United Kingdom**, with no drastic movements, except for a slight late surge in the years from 2010-2014, which is attributed to new wave of refugee migrations affecting entire Europe from Middle-East.
#
# Also **South Africa** shows a positive trend for the period 2004-2014, and then shows a minor drop.
#
# **Canada** and **Sri Lanka** don't resemble any major growth or decline, while **Australia** shows a significant growth from 2012 onwards.
#
# *Note:* I haven't included **China** for analysis, the prime rea thatson being the graph for China was overfitting the charts and dwarfing the statistics of other countries to a critical degree, which eventually made it hard to analyze other countries' trends. It is however clear from the data that China is way ahead of most countries, when it comes to propagation of education. Hence, I have only selected countries for analysis that are closely comparable, especially when it comes to India and United States.

# %% [markdown]
# 2. Percentage of enrolment in pre-primary education in private institutions.

# %%
# Here we can directly pass the values as 'temp' and 't',
# since we extracted those values during test run, there's no need to call the same function again.
# Since its a percentage(%) data hence we are extracting it in row-wise manner
# such that "Years" would be columns and we can select columns for analysis asper required.

Indicator2 , Title2 = get_columnwise_data(Indicators[1], EdStatsData, Countries)

# Displaying Title of Indicator.
print(Title2)

# Displaying the DataFrame recieved.
Indicator2
# Out:
# Percentage of enrolment in pre-primary education in private institutions (%)
#     Year  Australia   Canada    Germany      India      Japan  South Africa  \
# 0   1972        NaN  2.35687        NaN   0.000000  75.923576           NaN
# 1   1973        NaN  2.26478        NaN   0.000000  76.596039           NaN
# 2   1974  21.940889  2.00116        NaN        NaN  75.941681           NaN
# 3   1975  19.497250  2.56210        NaN        NaN  75.692436           NaN
# 4   1976  18.816019  2.47142        NaN        NaN  75.105850           NaN
# 5   1977  18.768770  2.57639        NaN        NaN  74.490334           NaN
# 6   1978  19.001471  2.46426        NaN        NaN  74.193039           NaN
# 7   1979  21.520741  2.53272        NaN        NaN  73.799019           NaN
# 8   1980  22.473480  2.54271        NaN        NaN  73.456047           NaN
# 9   1981  23.242620  2.79309        NaN        NaN  73.428322           NaN
# ...

# %%
# Step 1: Check and display columns
print(Indicator2.head())
# Also we are selecting limited number of columns for analysis so the repetative mean values won't affect much of our visualization.
# Out:
#    Year  Australia   Canada  Germany  India      Japan  South Africa  \
# 0  1972        NaN  2.35687      NaN    0.0  75.923576           NaN
# 1  1973        NaN  2.26478      NaN    0.0  76.596039           NaN
# 2  1974  21.940889  2.00116      NaN    NaN  75.941681           NaN
# 3  1975  19.497250  2.56210      NaN    NaN  75.692436           NaN
# 4  1976  18.816019  2.47142      NaN    NaN  75.105850           NaN
#
#    Sri Lanka  United Kingdom  United States
# 0        NaN             NaN       31.34041
# 1        NaN             NaN            NaN
# 2        NaN             NaN       31.81818
# 3        NaN             NaN            NaN
# 4        NaN         5.39608       33.10640

# %%
# We see a lot of NaN values in the first 5 rows of each column itself.
# Now, we need to replace 'NaN' values from the matrix, by the respective mean of all numeric values of each column to fill null values
# since average of values provide a better estimation for the type of data we have in a row wise matrix.
# However we will first have to check the datatypes to see if they are numeric or not

# Step 2: Checking the Column Datatypes
print(Indicator2.dtypes)
# Out:
# Year               object
# Australia         float64
# Canada            float64
# Germany           float64
# India             float64
# Japan             float64
# South Africa      float64
# Sri Lanka         float64
# United Kingdom    float64
# United States     float64
# dtype: object

# %%
# It's clear that the datatypes of values in columns are non-numeric

# Step 3: Converting all values to numeric. Ensure numeric conversion where possible, otherwise NaNs remain
Indicator2 = Indicator2.apply(lambda x: pd.to_numeric(x, errors='coerce'))

#Step 4: Checking the datatypes again
print(Indicator2.dtypes)
# Out:
# Year                int64
# Australia         float64
# Canada            float64
# Germany           float64
# India             float64
# Japan             float64
# South Africa      float64
# Sri Lanka         float64
# United Kingdom    float64
# United States     float64
# dtype: object

# %%
# Now the data is readily available in numeric terms in order to in order to calculate the mean
# of each column in the Indicator2 Dataframe

# Step 4: Filling NaN values with the mean of the respective column
Indicator2 = Indicator2.apply(lambda x: x.fillna(x.mean()))

# Step 5: Verify if NaNs are filled correctly
print(Indicator2.isnull().sum())
# Out:
# Year              0
# Australia         0
# Canada            0
# Germany           0
# India             0
# Japan             0
# South Africa      0
# Sri Lanka         0
# United Kingdom    0
# United States     0
# dtype: int64

# %%
# It's clear that there are no NaN values now. Hence, Displaying cleaned matrix.
Indicator2
# Out:
#     Year  Australia    Canada    Germany      India      Japan  South Africa  \
# 0   1972  45.277192  2.356870  61.141664   0.000000  75.923576      8.166591
# 1   1973  45.277192  2.264780  61.141664   0.000000  76.596039      8.166591
# 2   1974  21.940889  2.001160  61.141664  46.062090  75.941681      8.166591
# 3   1975  19.497250  2.562100  61.141664  46.062090  75.692436      8.166591
# 4   1976  18.816019  2.471420  61.141664  46.062090  75.105850      8.166591
# 5   1977  18.768770  2.576390  61.141664  46.062090  74.490334      8.166591
# 6   1978  19.001471  2.464260  61.141664  46.062090  74.193039      8.166591
# 7   1979  21.520741  2.532720  61.141664  46.062090  73.799019      8.166591
# 8   1980  22.473480  2.542710  61.141664  46.062090  73.456047      8.166591
# 9   1981  23.242620  2.793090  61.141664  46.062090  73.428322      8.166591
# 10  1982  24.322960  3.305110  61.141664  46.062090  73.720543      8.166591
# ...

# %%
# Extracting year list for column names
cols_2 = list(Indicator2['Year'])

# Transpose the dataframe and also reset the indexes of the columns
Indicator2_rowtable = Indicator2.T.reset_index()

# Setting new column names (Years)
Indicator2_rowtable.columns = ["Country Name"] + cols_2

Indicator2_rowtable.drop(0, inplace=True)
Indicator2_rowtable.reset_index(drop=True, inplace=True)

# Displaying the DataFrame recieved.
Indicator2_rowtable
# Out:
#      Country Name       1972       1973       1974       1975       1976  \
# 0       Australia  45.277192  45.277192  21.940889  19.497250  18.816019
# 1          Canada   2.356870   2.264780   2.001160   2.562100   2.471420
# 2         Germany  61.141664  61.141664  61.141664  61.141664  61.141664
# 3           India   0.000000   0.000000  46.062090  46.062090  46.062090
# 4           Japan  75.923576  76.596039  75.941681  75.692436  75.105850
# 5    South Africa   8.166591   8.166591   8.166591   8.166591   8.166591
# 6       Sri Lanka   2.483747   2.483747   2.483747   2.483747   2.483747
# 7  United Kingdom  15.779896  15.779896  15.779896  15.779896   5.396080
# 8   United States  31.340410  36.167102  31.818180  36.167102  33.106400
#
#         1977       1978       1979       1980  ...       2006       2007  \
# 0  18.768770  19.001471  21.520741  22.473480  ...  82.214394  76.055313
# 1   2.576390   2.464260   2.532720   2.542710  ...   5.820340   5.820400
# ...

# %% [markdown]
# Now that the matrix is ready with all numeric values filled, we can now visualize the data into graphs. We shall now use the following for visualizations -
# 1. A bar graph depicting a yearly comparison of this indicator with years - from 1985 to 2015 into consideration for each country separately. This is done in order to find growth trends for each individual country over the years.
# 2. A bar graph depicting country-comparisons for the indicator for 3 significant years (1985, 2000, 2015), which would represent the countries' growth analysis over the peried of 30 years, since a year-by-year visual comparison of country data is not possible to be analyzed.

# %%
# Plotting the bar graph.
# Code for plotting multiple countries over the years
IND_Bar = Indicator2.plot(x='Year',  # Year should be on the X-axis
                y="India",  # List of Y values (countries)
                xlabel="Years",
                ylabel="% of Enrolment",
                kind='bar',
                title=Title2 + " " + '-' + " " + Countries[0],
                figsize=(12, 7),
                grid=True,
                colormap="cividis_r",
                width=0.8,
                fontsize=11).patch.set_facecolor('#f0ffff')

US_Bar = Indicator2.plot(x='Year',  # Year should be on the X-axis
                y="United States",  # List of Y values (countries)
                xlabel="Years",
                ylabel="% of Enrolment",
                kind='bar',
                title=Title2 + " " + '-' + " " + Countries[1],
                figsize=(12, 7),
                grid=True,
                colormap="cividis_r",
                width=0.8,
                fontsize=11).patch.set_facecolor('#f0ffff')

UK_Bar = Indicator2.plot(x='Year',  # Year should be on the X-axis
                y= "United Kingdom",  # List of Y values (countries)
                xlabel="Years",
                ylabel="% of Enrolment",
                kind='bar',
                title=Title2 + " " + '-' + " " + Countries[2],
                figsize=(12, 7),
                grid=True,
                colormap="cividis_r",
                width=0.8,
                fontsize=11).patch.set_facecolor('#f0ffff')

AUS_Bar = Indicator2.plot(x='Year',  # Year should be on the X-axis
                            y= "Australia", # List of Y values (countries)
                            xlabel="Years",
                            ylabel="% of Enrolment",
                            kind='bar',
                            title=Title2 + " " + '-' + " " + Countries[3],
                            figsize=(12, 7),
                            grid=True,  # Grid for better visualization
                            colormap="cividis_r",
                            width=0.8,
                            fontsize=11).patch.set_facecolor('#f0ffff')

GER_BAR = Indicator2.plot(x='Year',  # Year should be on the X-axis
                            y="Germany", # List of Y values (countries)
                            xlabel="Years",
                            ylabel="% of Enrolment",
                            kind='bar',
                            title=Title2 + " " + '-' + " " + Countries[4],
                            figsize=(12, 7),
                            grid=True,  # Grid for better visualization
                            colormap="cividis_r",
                            width=0.8,
                            fontsize=11).patch.set_facecolor('#f0ffff')

SA_BAR = Indicator2.plot(x='Year',
                            y="South Africa", # List of Y values (countries)
                            xlabel="Years",
                            ylabel="% of Enrolment",
                            kind='bar',
                            title=Title2 + " " + '-' + " " + Countries[5],
                            figsize=(12, 7),
                            grid=True,  # Grid for better visualization
                            colormap="cividis_r",
                            width=0.8,
                            fontsize=11).patch.set_facecolor('#f0ffff')

CAN_BAR = Indicator2.plot(x='Year',
                            y="Canada", # List of Y values (countries)
                            xlabel="Years",
                            ylabel="% of Enrolment",
                            kind='bar',
                            title=Title2 + " " + '-' + " " + Countries[6],
                            figsize=(12, 7),
                            grid=True,  # Grid for better visualization
                            colormap="cividis_r",
                            width=0.8,
                            fontsize=11).patch.set_facecolor('#f0ffff')

JPN_BAR = Indicator2.plot(x='Year',
                            y="Japan", # List of Y values (countries)
                            xlabel="Years",
                            ylabel="% of Enrolment",
                            kind='bar',
                            title=Title2 + " " + '-' + " " + Countries[7],
                            figsize=(12, 7),
                            grid=True,  # Grid for better visualization
                            colormap="cividis_r",
                            width=0.8,
                            fontsize=11).patch.set_facecolor('#f0ffff')

SL_BAR = Indicator2.plot(x='Year',
                            y="Sri Lanka",  # List of Y values (countries)
                            xlabel="Years",
                            ylabel="% of Enrolment",
                            kind='bar',
                            title=Title2 + " " + '-' + " " + Countries[8],
                            figsize=(12, 7),
                            grid=True,  # Grid for better visualization
                            colormap="cividis_r",
                            width=0.8,
                            fontsize=11).patch.set_facecolor('#f0ffff')

# A bar-charrt showing country-comparisons for the indicator for 3 significant years (1985, 2000, 2015),
# which would represent the countries' growth over 30 years (basically start, mid, end)
Country_Year_Comparison = Indicator2_rowtable.plot(x='Country Name',
                            y = [1985, 2000, 2015], # List of Y values (years)
                            xlabel="Countries",
                            ylabel="% of Enrolment",
                            kind='bar',
                            title=Title2 + " Across Years - For Selected Countries",
                            figsize=(12, 7),
                            grid=True, colormap= "cividis_r",width = 0.8, fontsize=11)
# # Show the plot
plt.show()

# Calling the respective charts -
# IND_Bar
# US_Bar
# UK_Bar
# AUS_Bar
# GER_BAR
# SA_BAR
# CAN_BAR
# JPN_BAR
# SL_BAR

# Above statement will create and display the graph.
# x:- list of years
# y:- list of countries selected
# colormap:- colour scheme for the bars.
# width:- Bar width.

# %% [markdown]
# **Observations**:
# ******
# 1. **Australia** - The country has witnessed a steady growth of enrolments in private educational institutions. Except for the early years from 1974-1980 which showed a slight but noticeable dip, the trajectory shows an ever increasing trend with a few periods of constantly same numbers, like the decade between 1984-1994, and then an upshoot of growth in enrolments from 1995-2000, after which the numbers again show a significant growth in enrolments from 2001 onwards, never to fall below the 70% enrolment mark in the last 10 years of observation, except for the year 2013.
#
# 2. **India** - For the first 2 years, there are 0 pre-primary enrolments at private institutions. This is followed by a surge to 46.06% enrolments in the year 1974 which remains throughout the period till 2012, wherein we have just assumed the mean (46.06%) for the years as data for this indicator wasn't exactly available for India. One excellent way of looking at this, is that most pre-primary children got enrolled in government funded institutions till 2012,, inspite of private educational institutions still being popular. Post 2012, we can see an upsurge as more number of private institutions are established, people's awareness about educational offerings such as ICSE and CBSE is more widespread, apart from the traditional state board of education (SSC), which in turn, leads to an increase in enrolments at institutes/universities offering ICSE courses.
#
# 3. **Japan** - Enrolments begin with a mild increase to 76% in 1974, post which there is a trajectory of mild decreases until 1982. 1983 marks a noticeable increase in enrolments uptil 1997, after which there is a sudden drop in 1998 to below the 70% enrolment threshold (around 65% figure mark). From 1998 onwards till 2003 the numbers are consistent, and there is a steady increase of enrolments till the end of the observation period, with the last five years (2011-2015), showing a recovery in the enrolment numbers which cross the threshold of 70%. The population decline post 1998, fall in life expectancy and higher mortality rate are largely to be blamed for the sudden fall in 1998.
#
# 4. **Germany** - The numbers for Germany are stable until 1994, psot which there is a slight increase in 1995 and 1996. This is followed by a remarkable drop in enrolments in 1997, which stabilises till 1999. The number rises in the year 2000 and remains table throughout till 2005, after which again the number of enrolments jump in 2006. From 2006 onwards till the end of the period, there is a continnuous steady increase in the enrolments, primarily owing to the large migration populace in Germany, the educational needs of which the country now has to cater to.
#
# 5. **United States** - THe US shows a consistently volatile picture of growth in enrolments with slight rises and dips occurring every alternative year. Significant threshold crossings of 40% occur in 1998, 2002 and in the last 2 years of the observation period (2014, 2015). The time period from 2005-2013 manifests a consistent number of around 36% enrolments for each year in the said period. Overall, the chart for the US is the most volatile chart in comparison to other countries' charts, as it is largely marked with short unpredictable ups and downs in enrolment numbers.
#
# 6. **United Kingdom** - During the first 12 years of observation until 1984, the number of enrolments are pretty much consistent across years except for the year 1976. Post 1984, UK experiences a sizeable fall in number of pre-primary enrolments at private institutions until a trend of mild increases continues up until 1992. After 1992, there is a sudden surge in pre-primary enrolments back to the consistent levels of 1972 for another period of 6 years (1993-1998) post which a fall occurs again in 1999, followed by a trend of mild increases yet again uptil 2004. The years 2005 and 2007 witness a rise back to 1972 levels. Post-2007, the number of pre-primary enrolments at private institutions show a huge spike year-after-year uptil 2013, where the highest number of enrolments are met crossing the threshold of 50% for the first time in the observation period. Thereafter, steady dips occur, thus bringing back the enrolment levels back to 1972 levels in the year 2015.
#
# 7. **South Africa** - The figures of around 7% are more or less maintained uptil 1997, after which there is a significant shoot in 1998 numbers crossing the 25% threshold and a considerable drop to 11% in year 2000 and 2001.  2002 is the year, when the numbers first fall below the 1972 threshold of 7% and the decline continues till 2009 without a relatively precedented significant increase during that time period. Post 2009 till end of observation period, the numbers show a mild increase, when in 2015 finally the numbers more or less arrive back to 1972 levels of 7%.
#
# 8. **Canada** - The country's indicator trajectory shows a rising trend overall inspite of volatility during the first 10 years. The years where the trend breaches the the thresholds of 3%, 4% , and 5% are 1982, 1991 and 1998 respectively. Post 1998, there is a huge spike in the enrolment levels, where the thresholds of 7 % is breached in 2 consecutive years (1999, 2000), after which the numbers fall below the 5% mark, and remain stable for 4 years. However, though the levels breach the 5% mark again and in 2009, it breaches 7% threshold yet again. Post 2009, the levels fall and at the end of the observation period, the levels are back below 5% (2001 levels).
#
# 9. **Sri Lanka** - From the start of the observation period till 2009, the numbers are just below the 2.5% mark, post whihc there is a significant drop to just above 1.5% for 2 consecutive years (2010, 2011). The enrolment numbers spike to more than 2.5% over the next 2 years (2012, 2013) and then breach the 3% mark in subsequent years (2014, 2015). The fall in 2010 and 2011 could be attributed to the Srilankan economy being badly hit by the global financial situation, as a result of which household spending including expendture on education encounters a setback.
#
# 10. Country Comparisons - Out of the above selected countries for analysis, India, Australia, Germany, UK, US to a major extent and Sri Lanka to a marginal extent have shown an increasing trend till end of the period, all of them reaching their major highs towards the end of the period. Canada and South Africa on the other hand show an increase from 1985 to 2000 and then a fall from 2000 to 2015. Japan, initially experiences a decrease upto 2000, however it has recovered enrolment numbers sizeably from 2000 till 2015.

# %% [markdown]
# ###**Expenditures**
# ******
# It signifies the amount spent by federal government on public educational institutions and other education related institutions. Education plays a very important role for a country to be able to
# absorb technology and develop the capacity for the realization
# of development and sustainable growth. Also, Human capital is a
# productive investment in people that includes knowledge,
# skills, abilities, ideas, health which often results from
# expenditures in education.

# %% [markdown]
# 1. **Government expenditure on education as % of GDP.**

# %%
# Extracting Indicator matrix.
Indicator3 , Title3  = get_columnwise_data(Indicators[2], EdStatsData, Countries)

# Displaying Title of Indicator.
print(Title3)

# Displaying the DataFrame recieved.
Indicator3
# Out:
# Government expenditure on education as % of GDP (%)
#     Year  Australia   Canada  Germany    India    Japan  South Africa  \
# 0   1972        NaN  7.63406      NaN      NaN  4.07991           NaN
# 1   1973        NaN  7.03377      NaN      NaN  4.11199           NaN
# 2   1974        NaN  6.70673      NaN      NaN  4.12426           NaN
# 3   1975        NaN  6.43802      NaN      NaN  4.73971           NaN
# 4   1976        NaN  6.71431      NaN      NaN  4.93977           NaN
# 5   1977        NaN  6.72308      NaN      NaN  4.92031           NaN
# 6   1978    6.01461  7.09923      NaN      NaN  4.98988           NaN
# 7   1979    5.89238  6.72539      NaN      NaN  5.13707           NaN
# 8   1980    5.68220  6.47863      NaN      NaN  5.16240           NaN
# 9   1981        NaN  6.43443      NaN      NaN  5.15984           NaN
# 10  1982    5.48487  6.52129      NaN      NaN  5.11901           NaN
# 11  1983    5.36023  6.87640      NaN      NaN  4.90379           NaN
# ...

# %%
# Cleaning data to replace null values using backward and forward filling methods.
# First using "ffill" on data.
Indicator3.fillna(method = "ffill", inplace = True)

# now using "bfill" on data.
Indicator3.fillna(method = "bfill", inplace = True)

# Displaying cleaned matrix.
Indicator3
# Out:
# <ipython-input-32-da01e64aa139>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Indicator3.fillna(method = "ffill", inplace = True)
# <ipython-input-32-da01e64aa139>:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Indicator3.fillna(method = "bfill", inplace = True)
#     Year  Australia   Canada  Germany    India    Japan  South Africa  \
# 0   1972    6.01461  7.63406  4.41016  3.30847  4.07991       5.34765
# 1   1973    6.01461  7.03377  4.41016  3.30847  4.11199       5.34765
# 2   1974    6.01461  6.70673  4.41016  3.30847  4.12426       5.34765
# 3   1975    6.01461  6.43802  4.41016  3.30847  4.73971       5.34765
# 4   1976    6.01461  6.71431  4.41016  3.30847  4.93977       5.34765
# 5   1977    6.01461  6.72308  4.41016  3.30847  4.92031       5.34765
# ...

# %%
# Plotting the graph.
Indicator3[26:].plot(x = "Year", y = ["India", "Germany", "United States", "Canada", "United Kingdom", "Australia", "South Africa", "Japan", "Sri Lanka"],
                kind = 'line', title = Title3,
                xlabel = "Years", ylabel = "% of GDP expenditure",
                subplots = True, layout = (3,3),
                ylim = (0, 8), linewidth = 0.5,
                figsize = (12,8), fontsize = 11,
                marker = "o", grid = True)

# we are using a line graph here for this indicator. as we need to compare the graphs
# of each country with each other to find out similarities/differences in trends
# We have used 'subplots' attribute to specify that we need to plot
# countries as subplots instead of all of them on same graph, hence set to True.
# also 'layout' specifies the matric structure of subplots.
# Out:
# array([[<Axes: xlabel='Years', ylabel='% of GDP expenditure'>,
#         <Axes: xlabel='Years', ylabel='% of GDP expenditure'>,
#         <Axes: xlabel='Years', ylabel='% of GDP expenditure'>],
#        [<Axes: xlabel='Years', ylabel='% of GDP expenditure'>,
#         <Axes: xlabel='Years', ylabel='% of GDP expenditure'>,
#         <Axes: xlabel='Years', ylabel='% of GDP expenditure'>],
#        [<Axes: xlabel='Years', ylabel='% of GDP expenditure'>,
#         <Axes: xlabel='Years', ylabel='% of GDP expenditure'>,
#         <Axes: xlabel='Years', ylabel='% of GDP expenditure'>]],
#       dtype=object)

# %% [markdown]
# **Observations:**
# ******
#
# 1. India - During the period 1997-1999, we can see the indicator rise and remain steady up until 2002, followed by a consistent decline until 2007. 2002 is the time around which national elections were held & there is a resulting political shift in India at the Centre with the Bhartiya Janata Party headed by Atal Bihari Vajpayee bowing out, and the Indian National Congress party led by Manmohan Singh assuming power at the Centre. In the period 2007-2011 we can see a continuous increase in govt. expenditure towards education, until the levels of spending stabilise over the consequent years.
#
# 2. Germany - The country shows stable spending levels until 2008 where the graph shows a sudden jump in spending till 2009, followed by a steady rise over the remaining years. Post 2008, it appears that the government has emphasized greater spending levels, as it is a sector mostly dependent on social contributions and government aid.
#
# 3. United States - The indicator movement for the US is quite consistent for the period 1997-2001, shortly followed by a leap, and significant fluctuations happening throughout the rest of the graph. We see the most volatility in US government spending towards education throughout the years, in comparison to the others.
#
# 4. Canada - A declining trend emerges during the period 1997-2008 and for the period 2008-2010, the Canadian government experiences a slight rise in spending levels, post which there is hardly any indicator movement.
#
# 5. United Kingdom - The UK experiences a decline in the period 1998-1999, post which the graph is showing a rising tendency until the end of 2015. We can observe two significant leaps, one at 2001-2002, and the other at 2009-2010, and minor fluctuations for the rest of the other periods.
#
# 6. Australia - A slight but significant drop between 1999-2000 followed by a period of relatively stable movement until the period beginning from 2005 until 2008 marks a steady decline. Post 2008, there is a remarkable leap in the period 2008-2010, followed by a drop again from 2010-2012. It is also noteworthy that the magnitude of the indicator as of 1997, and as of 2015, are relatively very, however the overall graph movement signifies a fair bit of volatility.
#
# 7. South Africa - The graphs begins with a sudden rise from 1998-1999 followed by a fall until 2003. From 2003 onwards we can observe a stable rise until 2006, after which there's a slight drop to the same levels of spending as of 2003. The chart from 2008 onwards shows a sharp rise in spending until 2012, followed by a slight drop till 2013 and stable spending continuing uptil 2015.
#
# 8. Japan - The graph for Japan can be considered to be rather relatively stable in comparison to other countries. There is a slight leap that we see between the years 2009-2010. It is also noteworthy that the magnitude of the indicator as of 1997, and as of 2015, are relatively similar. The overall graph shows a baseline movement, which marks a picture of stability in government spending.
#
# 9. Sri Lanka - The country has stable spending levels until 2008, after which the levels decline drastically under the threshold of 2% for the remaining years until it is breached in 2015. The graph highlights the change in focus of Sri Lanka's educational spending, the funds of which were largely contributed by revenues from tourism sector up and until 2008, when tourism in the country takes a major hit.

# %% [markdown]
# 2. **Expenditure on education as % of total government expenditure.**

# %%
# Extracting data in a rowwise manner.
Indicator4 , Title4  = get_columnwise_data(Indicators[3], EdStatsData, Countries)

# Displaying Title of Indicator.
print(Title4)

# Displaying the DataFrame recieved.
Indicator4
# Out:
# Expenditure on education as % of total government expenditure (%)
#     Year  Australia    Canada   Germany     India      Japan  South Africa  \
# 0   1982        NaN  15.53181       NaN       NaN  15.640620           NaN
# 1   1983        NaN  14.77497       NaN       NaN  14.914230           NaN
# 2   1984        NaN  14.09080       NaN       NaN        NaN           NaN
# 3   1985        NaN  13.23688       NaN       NaN        NaN           NaN
# 4   1986        NaN  12.68320       NaN       NaN        NaN           NaN
# 5   1987        NaN  13.45583       NaN       NaN  18.169790           NaN
# 6   1988   13.24973  13.53854       NaN       NaN  17.993971           NaN
# 7   1989   13.35092  13.56977       NaN       NaN  17.847120           NaN
# 8   1990   13.59172  13.19062       NaN       NaN        NaN           NaN
# 9   1991   14.06531  14.26380       NaN       NaN        NaN           NaN
# 10  1992   13.20402  13.11614       NaN       NaN        NaN           NaN
# ...

# %%
# Step 1: Ensure numeric conversion where possible, otherwise NaNs remain
Indicator4 = Indicator4.apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Step 2: Filling NaN values with the mean of the respective column
Indicator4 = Indicator4.apply(lambda x: x.fillna(x.mean()))

# Step 5: Verify if NaNs are filled correctly
print(Indicator4.isnull().sum())
# Out:
# Year              0
# Australia         0
# Canada            0
# Germany           0
# India             0
# Japan             0
# South Africa      0
# Sri Lanka         0
# United Kingdom    0
# United States     0
# dtype: int64

# %%
# It's clear that there are no NaN values. Hence, Displaying cleaned matrix.
# Displaying Title of Indicator.
print(Title4)

Indicator4
# Out:
# Expenditure on education as % of total government expenditure (%)
#     Year  Australia     Canada    Germany      India      Japan  South Africa  \
# 0   1982  13.695977  15.531810  10.064606  13.538788  15.640620     19.299002
# 1   1983  13.695977  14.774970  10.064606  13.538788  14.914230     19.299002
# 2   1984  13.695977  14.090800  10.064606  13.538788  11.493073     19.299002
# 3   1985  13.695977  13.236880  10.064606  13.538788  11.493073     19.299002
# 4   1986  13.695977  12.683200  10.064606  13.538788  11.493073     19.299002
# 5   1987  13.695977  13.455830  10.064606  13.538788  18.169790     19.299002
# 6   1988  13.249730  13.538540  10.064606  13.538788  17.993971     19.299002
# 7   1989  13.350920  13.569770  10.064606  13.538788  17.847120     19.299002
# 8   1990  13.591720  13.190620  10.064606  13.538788  11.493073     19.299002
# 9   1991  14.065310  14.263800  10.064606  13.538788  11.493073     19.299002
# ...

# %% [markdown]
# A horizontal bar graph is fitting to depict this indicator as it will help us check the levels of government expenditure on education as % of total across 3 years - comparison of countries for each separate year under consideration (2000, 2009, 2015).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual Indicator4 DataFrame)
# Assuming 'Year' is the index
Indicator4.set_index('Year', inplace=True)

# List of years to plot - we are choosing only three years as a representative of the observation period's start, mid and end
# so that we can deduce a reasonably fair picture
years = [2000, 2009, 2015]

# Set figure size
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(12, 15))

# Loop through each year and create a horizontal bar chart
for i, year in enumerate(years):
    Indicator4.loc[year].plot(kind='barh', ax=axes[i], colormap="tab10", legend=False)

    # Formatting
    axes[i].set_title(f"Education Spending - % of Gov. Expenditure in {year}", fontsize=14)
    axes[i].set_xlabel("% of Government Expenditure", fontsize=12)
    axes[i].set_ylabel("Countries", fontsize=12)
    axes[i].grid(axis="x", linestyle="--", alpha=0.7)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
# *******
#
# The countries that initially decreased their spending allocation towards education from year 2000 to 2009 and subsequently increased their spending levels to a considerable degree are ***India***, ***United States***, ***Canada***, and ***Sri Lanka***.
#
# Of these countries, the ***Indian*** government in comparison to others has clearly curtailed its spending allocation to a major degree (7.5% curtailment) in 2009 and brought back spending levels by 2.5% in 2015. ***Sri Lanka*** too has clearly reduced its spending levels to its lowest in 2009. of all countries, Sri Lanka has the lowest education spending allocation in 2009 and brings back allocation to more than 10% in 2015. I have selected year 2009 for the analysis here, as it is clearly the year, which brings in change in household spending habits as well as government policy changes in order to wrestle with the financial crisis begun in 2008.
#
# The spending levels of ***Australia***, ***South Africa*** and ***Germany*** have more or less remained consistent throughout the years. It is noteworthy that despite being the one of the top EU countries economically and also promoting an open borders policy post 2010, the German government has been able to maintain its spending levels in line throughout the observation period.
#
# ***Japan*** has been increasing its spending allocation till 2009, post which it maintains a stable and consistent spending level in 2015.
#
# ***United Kingdom*** is the only country to increase its spending levels across all the years, although the increases are relatively marginal in comparison to other nations.

# %% [markdown]
# ###**Literacy**
# ******
# Literacy is the process of expanding one's knowledge of reading and writing in order to develop their thinking and learning for the purpose of understanding themselves and the world.
# Higher literacy rates are associated with high populations, less crime rates, greater economic growth, and higher employment rates. For a person, literacy is a foundational skill required to acquire advanced skills.

# %% [markdown]
# ## 1.  **Adult literacy rate, population 15+ years, both sexes**

# %%
# Extracting Indicator matrix.
Indicator5 , Title5  = get_columnwise_data(Indicators[4], EdStatsData, Countries)

# Displaying Title of Indicator.
print(Title5)

# Displaying the DataFrame recieved.
Indicator5
# Out:
# Adult literacy rate, population 15+ years, both sexes (%)
#     Year  Australia  Canada  Germany      India  Japan  South Africa  \
# 0   1981        NaN     NaN      NaN  40.763592    NaN           NaN
# 1   1991        NaN     NaN      NaN  48.222069    NaN           NaN
# 2   1996        NaN     NaN      NaN        NaN    NaN      82.40210
# 3   2001        NaN     NaN      NaN  61.014560    NaN           NaN
# 4   2006        NaN     NaN      NaN  62.754470    NaN           NaN
# 5   2007        NaN     NaN      NaN        NaN    NaN      88.71725
# 6   2008        NaN     NaN      NaN        NaN    NaN           NaN
# 7   2009        NaN     NaN      NaN        NaN    NaN      92.89486
# 8   2010        NaN     NaN      NaN        NaN    NaN      92.87732
# 9   2011        NaN     NaN      NaN  69.302560    NaN      93.10214
# 10  2012        NaN     NaN      NaN        NaN    NaN      93.72947
# 11  2014        NaN     NaN      NaN        NaN    NaN      94.13990
# ...

# %%
# We see a lot of NaN values across rows and columns, so we would definitely want to conduct data cleaning here

# Step 1: Checking the Column Datatypes
print(Indicator5.dtypes)

# We can see the entire data is of numeric datatype (int, float) however dtype is shown as dtype:object
# Out:
# Year               object
# Australia         float64
# Canada            float64
# Germany           float64
# India             float64
# Japan             float64
# South Africa      float64
# Sri Lanka         float64
# United Kingdom    float64
# United States     float64
# dtype: object

# %%
# Step 3: Drop columns where all values are NaN
Indicator5.dropna(how="all", inplace=True, axis=1)
print(Indicator5)
# Out:
#     Year      India  South Africa  Sri Lanka
# 0   1981  40.763592           NaN  86.777924
# 1   1991  48.222069           NaN        NaN
# 2   1996        NaN      82.40210        NaN
# 3   2001  61.014560           NaN  90.682750
# 4   2006  62.754470           NaN  90.808830
# 5   2007        NaN      88.71725        NaN
# 6   2008        NaN           NaN  90.557950
# 7   2009        NaN      92.89486        NaN
# 8   2010        NaN      92.87732  91.181360
# 9   2011  69.302560      93.10214        NaN
# 10  2012        NaN      93.72947        NaN
# 11  2014        NaN      94.13990        NaN
# 12  2015        NaN      94.36792        NaN

# %%
# Drop rows where more than two value is NaN, i.e all values are Nan
# Even if only 2 columns in a row have null values, we shall not drop the row
# This is considering the fact that only 3 columns (Australia, South Africa, Canada) have values apart from the Year column
Indicator5.dropna(thresh=len(Indicator5.columns) - 2, inplace=True) # Allows 2 NaN values per row

# Since we still have NaN valuees, which affects the dataframe's datatype to show up as object, we have to convert all columns to numeric
# Convert all columns to numeric where possible (coerce non-convertible values to NaN)
Indicator5 = Indicator5.apply(pd.to_numeric, errors='coerce')

# Fill remaining NaN values with the column mean (only for numeric columns)
mean_values = Indicator5.mean(numeric_only=True)  # Compute means for numeric columns
Indicator5.fillna(mean_values, inplace=True)  # Fill NaN with means

# Display cleaned matrix
print(Indicator5.info())  # Check remaining NaN values
print(Indicator5.head())  # Preview cleaned data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          13 non-null     int64
#  1   India         13 non-null     float64
#  2   South Africa  13 non-null     float64
#  3   Sri Lanka     13 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 548.0 bytes
# None
#    Year      India  South Africa  Sri Lanka
# 0  1981  40.763592      91.52887  86.777924
# 1  1991  48.222069      91.52887  90.001763
# 2  1996  56.411450      82.40210  90.001763
# 3  2001  61.014560      91.52887  90.682750
# 4  2006  62.754470      91.52887  90.808830

# %%
# Display cleaned Dataframe
print(Indicator5)
# Out:
#     Year      India  South Africa  Sri Lanka
# 0   1981  40.763592      91.52887  86.777924
# 1   1991  48.222069      91.52887  90.001763
# 2   1996  56.411450      82.40210  90.001763
# 3   2001  61.014560      91.52887  90.682750
# 4   2006  62.754470      91.52887  90.808830
# 5   2007  56.411450      88.71725  90.001763
# 6   2008  56.411450      91.52887  90.557950
# 7   2009  56.411450      92.89486  90.001763
# 8   2010  56.411450      92.87732  91.181360
# 9   2011  69.302560      93.10214  90.001763
# 10  2012  56.411450      93.72947  90.001763
# 11  2014  56.411450      94.13990  90.001763
# 12  2015  56.411450      94.36792  90.001763

# %% [markdown]
# For this indicator, we would like to check the mean literacy rate of adults and also to ascertain, if there are any specific outliers in the data.

# %%
# Plotting Box Graph, since we have to check for outliers
Indicator5[["India", "South Africa", "Sri Lanka"]].plot(kind='box', title=Title5,
                ylabel="% of Adult Literacy", figsize=(16,15), fontsize=11, rot=0, grid=True, colormap="cividis").patch.set_facecolor('#f0ffff')

# %% [markdown]
# **Observations**:
# ******
#
# We are able to see that the highest literacy rate in the data for India, has an approximate magnitude of around 69%, and the lowest being approximately 40%. The median literacy rate, which has an approximate value of around 56%, is also the literacy rate for most of the years for India, which symbolises stability and consistency in literacy rate for the time period and is a positive indication of educational development.
#
# ***South Africa*** and ***Sri Lanka*** already have a better mean average literacy in comparison to India across years (above the 90% threshold), however their average is on the lower side of their literacy spectrum, indicating clearly a lower lack of scope for propagating further education, as almost all of the adult population is already literate (meaning very few people are illiterate). The lowest literacy rates for South Africa and Sri Lanka are 82% and 86% respectively.

# %% [markdown]
# 2. **Adult illiterate population, 15+ years, both sexes**

# %%
# Extracting columnwise matrix.
Indicator6 , Title6  = get_columnwise_data(Indicators[5], EdStatsData, Countries)

# Displaying Title of Indicator.
print(Title6)

# Displaying the DataFrame recieved.
Indicator6
# Out:
# Adult illiterate population, 15+ years, both sexes (number)
#     Year  Australia  Canada  Germany        India  Japan  South Africa  \
# 0   1981        NaN     NaN      NaN  255191968.0    NaN           NaN
# 1   1991        NaN     NaN      NaN  286798080.0    NaN           NaN
# 2   1996        NaN     NaN      NaN          NaN    NaN     4762538.0
# 3   2001        NaN     NaN      NaN  274237172.0    NaN           NaN
# 4   2006        NaN     NaN      NaN  287691648.0    NaN           NaN
# 5   2007        NaN     NaN      NaN          NaN    NaN     3798981.0
# 6   2008        NaN     NaN      NaN          NaN    NaN           NaN
# 7   2009        NaN     NaN      NaN          NaN    NaN     2490693.0
# 8   2010        NaN     NaN      NaN          NaN    NaN     2539631.0
# 9   2011        NaN     NaN      NaN  265567691.0    NaN     2496089.0
# 10  2012        NaN     NaN      NaN          NaN    NaN     2306826.0
# ...

# %%
# Drop rows where more than two value is NaN, i.e all values are Nan
# Even if only 2 columns in a row have null values, we shall not drop the row
# This is considering the fact that only 3 columns (Australia, South Africa, Canada) have values apart from the Year column
# Dropping countries that are all null.
Indicator6.dropna( how = "all", inplace = True, axis = 1)
Indicator6.dropna(thresh=len(Indicator6.columns) - 2, inplace=True) # Allows 2 NaN values per row

# Since we still have NaN valuees, which affects the dataframe's datatype to show up as object, we have to convert all columns to numeric
# Convert all columns to numeric where possible (coerce non-convertible values to NaN)
Indicator6 = Indicator6.apply(pd.to_numeric, errors='coerce')

# Fill remaining NaN values with the column mean (only for numeric columns)
mean_values = Indicator6.mean(numeric_only=True)  # Compute means for numeric columns
Indicator6.fillna(mean_values, inplace=True)  # Fill NaN with means

# Display cleaned matrix
print(Indicator6.info())  # Check remaining NaN values
print(Indicator6.head())  # Preview cleaned data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          13 non-null     int64
#  1   India         13 non-null     float64
#  2   South Africa  13 non-null     float64
#  3   Sri Lanka     13 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 548.0 bytes
# None
#    Year        India  South Africa  Sri Lanka
# 0  1981  255191968.0   2848723.375  1287998.0
# 1  1991  286798080.0   2848723.375  1328656.4
# 2  1996  273897311.8   4762538.000  1328656.4
# 3  2001  274237172.0   2848723.375  1297727.0
# 4  2006  287691648.0   2848723.375  1338896.0

# %%
# Display cleaned Dataframe.
Indicator6
# Out:
#     Year        India  South Africa  Sri Lanka
# 0   1981  255191968.0   2848723.375  1287998.0
# 1   1991  286798080.0   2848723.375  1328656.4
# 2   1996  273897311.8   4762538.000  1328656.4
# 3   2001  274237172.0   2848723.375  1297727.0
# 4   2006  287691648.0   2848723.375  1338896.0
# 5   2007  273897311.8   3798981.000  1328656.4
# 6   2008  273897311.8   2848723.375  1395557.0
# 7   2009  273897311.8   2490693.000  1328656.4
# 8   2010  273897311.8   2539631.000  1323104.0
# 9   2011  265567691.0   2496089.000  1328656.4
# 10  2012  273897311.8   2306826.000  1328656.4
# 11  2014  273897311.8   2226167.000  1328656.4
# 12  2015  273897311.8   2168862.000  1328656.4

# %% [markdown]
# A line graph will help us determine the population levels of each country and its trends over time.

# %%
# Plotting Line graph for Australia, South Africa, Canada.
Indicator6.plot(x = "Year", y = ["India", "South Africa", "Sri Lanka"], kind = 'line', title = Title6,
                xlabel = "Years", ylabel = "Illiterate Adults (100 Millions)",
                figsize=(10, 7), fontsize = 11, rot = 0,
                grid = True, colormap = "cividis", marker = "o", linewidth = 1).patch.set_facecolor('#f0ffff')

# %% [markdown]
# **Observations**:
# ******
# As per the above given graph, the number of illiterate adults in both South Africa and Sri lanka is sizeably low in comparison to India. Across all the years, the numbers for South Africa swing somewhat between 2 million to 4 million, while for Sri Lanka, the number of illiterates are consistently showing up around 1.3 million mark. Indicator movement is more or less stable over the years for both countries, except for a slight spike post 1995 for South Africa. For India however, the numbers are drastically higher (more than 250 million to 270 million), and therefore the graph shows a lot of volatility given the gigantic magnitude of population figures. The graph shows a coninuous rise form 1980 to just past 1990 and then a decline uptil just beyond the year 1995. The numbers for India spike up again till 280 million in 2006, post which there is a short decrease. The years from 2007 till 2015 maintain stable numbers at just above 270 million as evident from the straight line, except for a noticeable dip to 260 million figure mark in 2011.

# %% [markdown]
# ###**Population**
# ******
#
# Population of a country refers to the number of registered individuals living in that country. These individuals are bonafide registered citizens of the country and contribute to various aspects of country's Statistics.
#
# Population majorly affects the Education and literacy. Rapid growth of population increases the rate of illiteracy and poverty. It also increases the disparity between rich and poor countries in their socio- economic as well as general life. causes imbalance in its use.

# %% [markdown]
# **We've selected 4 indicator for this category, they are :-**
#
#
# * School age population, pre-primary education, both sexes (number)
# * School age population, primary education, both sexes (number)
# * School age population, secondary education, both sexes (number)
# * School age population, tertiary education, both sexes (number)

# %%
# Creating a list that would hold all 4 indicator matrices along with their titles.
Population_indicators = []

# Running a for loop that would extract values for all indicators and hold them in the Population_indicators list.
for indicator in Indicators[6:11]:

  # calling get_columnwise_data() on every population indicator.
  # Also appending them into the Population_indicators list.
  Population_indicators.append(get_columnwise_data(indicator, EdStatsData, Countries))

# print title of first indicator.
print(Population_indicators[0][1])

# Display first indicator matrix
Population_indicators[0][0]  # This prints the indicator matrix
# Out:
# Population of the official age for pre-primary education, both sexes (number)
# <ipython-input-18-0f97f2cc31c5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how='all', axis=1, inplace=True)
# <ipython-input-18-0f97f2cc31c5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=[col for col in cols_to_drop if col in df.columns], inplace=True)
#     Year  Australia    Canada    Germany       India      Japan  South Africa  \
# 0   1971   251115.0  865708.0  3842603.0  31836122.0  5188082.0      672199.0
# ...

# %% [markdown]
# As we can deduce now from the above table, the first index holds the dataframe and title for first population indicator.

# %%
# Since there's only one or two missing values, we can just fill them
# with the value available in previous row. It won't have much effect on our graph.
# Here this loop will fill null values for all indicators with their respective previous value.

for i in range(len(Population_indicators)):

  # Calling fillna function on all indicator matrices.
  Population_indicators[i][0].fillna(method = "ffill", inplace = True)

# Display Cleaned Matrix for first indicator.
Population_indicators[0][0]
# Out:
# <ipython-input-49-38507ced718a>:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Population_indicators[i][0].fillna(method = "ffill", inplace = True)
#     Year  Australia    Canada    Germany       India      Japan  South Africa  \
# 0   1971   251115.0  865708.0  3842603.0  31836122.0  5188082.0      672199.0
# 1   1972   251054.0  831302.0  3786292.0  32494288.0  5267009.0      694273.0
# 2   1973   250261.0  790105.0  3697424.0  33118470.0  5336434.0      716971.0
# 3   1974   249254.0  749323.0  3575594.0  33700136.0  5409003.0      738413.0
# 4   1975   248444.0  718258.0  3413043.0  34240160.0  5542572.0      756518.0
# 5   1976   250874.0  707713.0  3236478.0  34743112.0  5645246.0      777599.0
# 6   1977   254612.0  702801.0  2964479.0  35570288.0  5817110.0      797782.0
# 7   1978   258208.0  706416.0  2671381.0  36402984.0  5981775.0      816670.0
# ...

# %% [markdown]
# It is quite obvious from the above table that the data of most other countries (except China which is not included in analysis), seems insignificant in comparison to India's, when it comes to population statistics. Hence we can narrow down our analysis to the top 4 most significant and relevant countries. Hence for the Population data, we are considering a line graph for population time-series data for the following countries -
#
# *  India
# *  United States
# *  Japan
# *  Germany

# %%
# defining a subplot object such that we can plot all 4 indicators on the same figure.
figure, axes = plt.subplots(nrows = 2, ncols = 2)

# using tight_layout() to get more distinct graphs.
figure.tight_layout()

# a variable to call indexes of Population_indicators for various indicators.
k = 0

# Defining Nested for loops to plot (2,2) matric subplots.
for i in range(2):
  for j in range(2):

    # Plot function to plot various indicators.
    Population_indicators[k][0].plot(x = "Year",
                # passing list of countries selected to Y-axis.
                y = ["India", "United States", "Japan", "Germany" ],
                kind = 'line',
                # since every element of the list is a tuple that holds two values i.e, dataframe and Indicator name.
                # we can pass that indicator name as title. Also rejecting the string "(number)" from the end.
                ylabel = (Population_indicators[k][1])[:-9],
                xlabel = "Years", figsize = (15,10),
                rot = 0,
                grid = True,
                marker = ".",
                linewidth = 1,
                # 'ax' takes subplot indexes as input to plot graphs accordingly.
                ax = axes[i,j]).patch.set_facecolor('#f0ffff')

    # Incrementing 'k'.
    k = k + 1

# Below is the Graph obtained by all 4 indicators as subplots.

# %% [markdown]
# **Observations**
# ******
# For india, We observe a significantly steep incline in the population of official age for pre-primary education for India, in the period 1997-1998. This is also the time period when healthcare awareness and disease control campaigns are undertaken in full swing in India, thus resulting in a spike in population and general life expectancy of people. We are also able to see that across all the graphs, india is on a consistant incline. For the countries Japan, United States and Germany, we see an overall stable trend with minor fluctuations. This shows a potential focus towards stability and consistency in the population.

# %% [markdown]
# ###**Learning Outcomes**
# ****
# The Learning Outcomes category highlights levels of student learning in reading and mathematics in over 100 countries based on data from international learning assessments like PISA.
#
# We have considered two indicators in this category - PISA Mean Performance in Reading and PISA Mean Performance in Mathematics. We would also plot a bar chart for all the available countries for these both indicators, and also plot a pie chart in which we would group the countries according to their respective continents and represent the continents' share of mean performances (for both reading and mathematics separately) on pie charts.

# %% [markdown]
# 1. **PISA: Mean performance on the reading scale**

# %%
#creating a sub dataframe for the 'PISA: Mean performance on the reading scale' indicator
tempdf2 = EdStatsData.loc[EdStatsData['Indicator Code'] == Indicators[-2]].copy()
# print(tempdf2)

#saving the Indicator name to 'Title8'
Title8 = EdStatsData.loc[EdStatsData['Indicator Code'] == Indicators[-2]]["Indicator Name"][2301]
# print(Title8)

#creating colrange for the data columns
col = tempdf2.loc[: , "1970":"2100"]

#populating a new colum 'PISA_REA_mean', with row mean value for the column range
tempdf2['PISA_REA_mean'] = col.mean(axis=1)

#getting the rows that have a not-null 'PISA_REA_mean'
tempdf2 = tempdf2[pd.notnull(tempdf2['PISA_REA_mean'])]

#taking just the country name and 'PISA_REA_mean'
PISA_REA_pie = tempdf2[['Country Name', 'PISA_REA_mean']]

# Selecting the top 20 countries based on PISA scores
# Creating a new dataframe for piechart, with top 20 values for 'PISA_REA_mean'
PISA_REA_pie = PISA_REA_pie.sort_values(by="PISA_REA_mean").tail(20)

#setting 'Country Name' as index (for barplot)
PISA_REA=PISA_REA_pie.set_index('Country Name')

#sorting top 20 values

#creating figure and axes objects for bargraph
figure, axes = plt.subplots(nrows = 2, ncols = 1, figsize=(12, 9))
figure.tight_layout()

#plotting bargraph
PISA_REA.plot(kind='bar', ylim = (480, 550), xlabel = "Countries",
                    title = Title8, rot = 60, colormap = "Blues_r", legend = True,
                    fontsize = 12, ax = axes[0]).patch.set_facecolor('#f0ffff')

#populating 'Continent' column with continents for each country
contdict = {'Denmark':'Europe','Slovenia':'Europe','Germany':'Europe','Iceland':'Europe','Vietnam':'Asia','Poland':'Europe','Macao SAR, China':'Asia','Switzerland':'Europe','Norway':'Europe','United Kingdom':'Europe','Sweden':'Europe','Belgium':'Europe','Liechtenstein'	:'Europe','Netherlands':'Europe','Estonia':'Europe','Japan':'Asia','Australia':'ANZ','Ireland':'Europe','New Zealand':'ANZ','Canada':'North America','Hong Kong SAR, China':'Asia','Singapore':'Asia', 'Korea, Rep.':'Asia','Finland':'Europe','China':'Asia'	}
PISA_REA_pie['Continent']=PISA_REA_pie['Country Name'].map(contdict).fillna('Unknown')

#grouping by continents, and plotting pie chart
continent_REA_scores = PISA_REA_pie.groupby('Continent')['PISA_REA_mean'].sum()

# Dynamically setting explode values
explode_REA_values = [0.02] * len(continent_REA_scores)

# Plotting Pie Chart
continent_REA_scores.plot(kind='pie', ylabel = "Mean Performance Share by Continents - Reading", figsize=(16, 14), autopct='%1.1f%%',
                      explode=explode_REA_values, textprops={'fontsize': 14},
                      legend=False, ax=axes[1])
# Out:
# <Axes: ylabel='Mean Performance Share by Continents - Reading'>

# %% [markdown]
# **Observations:**
# ******
# We see that the values for the top 20 Countries, based on the 'PISA:Mean Performance on the Reading Scale', lie in the range of 495 - 540. It helps us understand the typical range of the highest scores for the indicator.
#
# Also, in the top 20, We have predominantly European countries (11 of the 20 are European Countries), followed by Asian countries (6), Australia and New Zealand from the ANZ region, and Canada from North America.
#
# However, considering just the top 5 countries, we can observe that 4 of them, are Asian, specifically in the East/South-East Asia regions.
#
# So 4 out of the 6 Asian countries, are in the Top 5, and Asian Countries except Macao, are in the Top 10
#
# We also see that Finland, which is at #2, is the only European country which is in the Top 5.

# %% [markdown]
# 2. **PISA: Mean performance on the Mathematics scale.**

# %%
#creating a sub dataframe for the 'PISA: Mean performance on the Mathematics scale' indicator
tempdf3 = EdStatsData.loc[EdStatsData['Indicator Code'] == Indicators[-1]].copy()
#print(tempdf3)

#saving the Indicator name to 'Title9'
Title9 = EdStatsData.loc[EdStatsData['Indicator Code'] == Indicators[-1]]["Indicator Name"][2298]
#print(Title9)

#creating colrange for the data columns
col = tempdf3.loc[: , "1970":"2100"]

#populating a new colum 'PISA_MAT_mean', with row mean value for the column range
tempdf3['PISA_MAT_mean'] = col.mean(axis=1)

#getting the rows that have a not-null 'PISA_MAT_mean'
tempdf3 = tempdf3[pd.notnull(tempdf3['PISA_MAT_mean'])]

#taking just the country name and 'PISA_MAT_mean'
PISA_MAT_pie = tempdf3[['Country Name', 'PISA_MAT_mean']]

# Selecting the top 20 countries based on PISA scores
# Creating a new dataframe for piechart, with top 20 values for 'PISA_MAT_mean'
PISA_MAT_pie = PISA_MAT_pie.sort_values(by="PISA_MAT_mean").tail(20)

#setting 'Country Name' as index (for barplot)
PISA_MAT = PISA_MAT_pie.set_index('Country Name')

#sorting top 20 values

#creating figure and axes objects for bargraph
figure, axes = plt.subplots(nrows = 2, ncols = 1, figsize=(12, 9))
figure.tight_layout()

#plotting bargraph
PISA_MAT.plot(kind='bar', ylim = (480, 600), xlabel = "Countries",
                    title = Title9, rot = 60, colormap = "Blues_r", legend = True,
                    fontsize = 12, ax = axes[0]).patch.set_facecolor('#f0ffff')

#populating 'Continent' column with continents for each country
contdict = {'Denmark':'Europe','Slovenia':'Europe','Germany':'Europe','Iceland':'Europe','Vietnam':'Asia','Poland':'Europe','Macao SAR, China':'Asia','Switzerland':'Europe','Norway':'Europe','United Kingdom':'Europe','Sweden':'Europe','Belgium':'Europe','Liechtenstein'	:'Europe','Netherlands':'Europe','Estonia':'Europe','Japan':'Asia','Australia':'ANZ','Ireland':'Europe','New Zealand':'ANZ','Canada':'North America','Hong Kong SAR, China':'Asia','Singapore':'Asia', 'Korea, Rep.':'Asia','Finland':'Europe','China':'Asia'	}
PISA_MAT_pie['Continent']=PISA_MAT_pie['Country Name'].map(contdict).fillna('Unknown')

#grouping by continents, and plotting pie chart
continent_MAT_scores = PISA_MAT_pie.groupby('Continent')['PISA_MAT_mean'].sum()

# Dynamically setting explode values
explode_MAT_values = [0.02] * len(continent_MAT_scores)

# Plotting Pie Chart
continent_MAT_scores.plot(kind='pie', ylabel = "Mean Performance Share by Continents - Mathematics", figsize=(16, 14), autopct='%1.1f%%',
                      explode=explode_MAT_values, textprops={'fontsize': 14},
                      legend=False, ax=axes[1])
# Out:
# <Axes: ylabel='Mean Performance Share by Continents - Mathematics'>

# %% [markdown]
# **Observations:**
# ******
# We see that the values for the top 20 Countries, based on the 'PISA:Mean Performance on the mathematics Scale', lie in the range of 500-580.
#
# In the top 20, European countries dominates the statistic (10 of the 20 are European Countries), followed by Asian countries (7), Australia and New Zealand from the ANZ region, and Canada from North America.
#
# However, considering just the top 5 countries, we can observe that all 5 of them, are Asian, specifically in the East/South-East Asia regions, which are also considered to be a part of emerging economies.
#
# It is noteworthy that 5 of the 7 Asian countries, are in the Top 5, and all Asian Countries except Vietnam, are in the Top 10.

# %% [markdown]
# ##**Conclusions of the Analysis:-**
# ****
# From the analysis we are able to conclude that **India** is one of the most significantly developing countries with a vast population and growing levels of student enrolments year-after-year, second only to US. India has shown positive growth over the the period of last 20 years (considering from 1995 to 2015) in most of the indicators considered for analysis (except for literacy rate). The early childhood enrolment rate of India reveals a significant growth trend and any kind of investment can prove to be an incredible shot in the arm for its education sector, which signifies that more people are growing conscious towards education and the literacy rate has improved considerably. We can see similar & even better enrolment trends for countries like the **United States of America**, which makes clear that the US is currently more prominent and developed in terms of education. However, the outstanding growth of India over the years shows great potential for the education sector and interested business organizations can take advantage of the education situation in the country. China, which has not been included in the analysis is also a great investment destination for education, the 2 key reasons being that it has the world's greatest concentration of population as of 2015, and the government spending on education is also significant. Thirdly, the quality of education imparted is excellent in the country.
#
# Following are the key takeaways of our analysis. Possible key reasons/explanations for changes in chart trends have been based on materials in news articles from Google searches:
#
# * The trend in enrolment numbers in early Childhood education for India and US, is significantly positive. It is evident that India is making remarkable and positive growth in this field as it's enrolment figures in year 2015 have nearly tripled from year 2000, thereby signalling great potential for investment in education.
#
# * With respect to enrolments In pre-primary education in private institutions, we observed that the enrollment during the 2015 has been twice than that of the year 2000, as the private sector in education expands with more establishments and offerings in ssimultaenous correspondence with greater awareness among the masses regarding schooling options.
#
# * From 2008-2012, India manifests a significant drop in enrolment numbers, primarily affected by curtailment in household spending experienced by lower-income groups, which is in turn triggered by the worsening global financial situation (after-effects of the US Suprime and credit crisis). However the ever increasing trajectory in the graph (2012-2014) is evidence of India's commitment towards early age education, eventually asserting its lead over other countries in coming years, while being second only to US & China.
#
# * The Indian govt expenditure on education as % of GDP is rising consistently after year 2008 and remains consistently stable after 2011, even though there were a few fluctuations in the past years.
#
# * The year 2008 has proven to be a pivotal year for most countries as 2009 marks government spending changes for almost every country in the analysis. The year 2008 thus marks a significant policy shift in education spending levels for almost all countries. A probable key reason for such a policy change is primarily the US subprime crisis and the following credit crisis leading to the closure of key financial institutions in the US and Europe, thus worsening the global financial situation. Policymakers of most governments under observation, thus have had felt the need to support more spending on education as it is a critical sector in most countries, except for Sri Lanka, which had reduced spending levels drastically and whose revenues primarily originate from tourism, a sector badly hit at the turn of 2008. It can be very well observed that Sri Lanka had been forced to reduce spending allocation towards education and probably divert the expenditure concentration into other key primary sectors such as tourism (possibly too attract more tourists, as a knee-jerk reaction). Hence, it can deduced that the importance and prioritisation of the education sector in the respective economies has considerably influenced the government's policy on education spending.
#
# * The total expenditure of the government on education(%), for India and Sri Lanka significantly decreased in 2009, than that of 2000, and the government expenditure by the United Kingdom has consistently increased over the years from 2000 to 2015.
#
# * Education in India has a lot of scope in comparison to other emerging economy countries (South Africa and Sri Lanka), as the literacy rate in India as per the latest figures in the observation period have only been around 56%. This means that businesses interested in education and considering investment, can utilize their funds/resources to promote education in the country to the remaining 44% (illiterate population).
#
# * After the year 2006 till 2012, we observe that the metric for illiterate population in India has been decreasing significantly, which could be attributed to the increase in the government expenditures, greater demand for education (in terms of enrolment numbers) and implementation of focused initiatives towards education across the country.
#
# * India has witnessed a significant population boost from 1997 to 1998 as it is evident from the graph for population numbers for pre-primary education. The sudden population spike can be attributed to a variety of factors such as widespread conduct of health campaigns, greater emphasis on health of women and children, effective initiatives such as vaccination drives and campaigns for disease eradication, which were very prevalent during those years.
#
# * Among the Asian countries, China holds the lead in PISA scores for Reading and also for Mathematics, while Finland has been the leader amongst European countries. It is worthy to note that India does not figure in the top 20 countries on both measures, which would only indicate that there is good scope for improvements in literacy and the education methods. Both China and Finland, on the other hand have been known to revolutionise their education system with more focus on implementation of education methods involving real-world practical applications instead of the usual tests & assessments based curriculum, thus improving the overall quality of education.
